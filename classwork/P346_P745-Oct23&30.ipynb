# %% [markdown]
# root finding for 2D nonlinear coupled equations

# %%
import numpy as np
import matplotlib.pyplot as plt
def f0(x0,x1):
    return x0**2-2*x0+x1**4-2*x1**2+x1
def f1(x0,x1):
    return x0**2+x0+2*x1**3-2*x1**2-1.5*x1-0.05
x0 = np.arange(-2.,3.,0.01)
x1 = np.arange(-2.,2.,0.01)
X0, X1 = np.meshgrid(x0,x1)
c1=plt.contour(x0, x1, f0(X0, X1),[0],colors=['b']);
c2=plt.contour(x0, x1, f1(X0, X1),[0],colors=['r']);
plt.clabel(c1, inline=True, fontsize=10)
plt.clabel(c2, inline=True, fontsize=10)
plt.xticks(np.arange(-2, 3.01, 0.5))
plt.yticks(np.arange(-2, 2.01, 0.25))
plt.xticks(np.arange(-2, 3, 0.1), minor=True)
plt.yticks(np.arange(-2, 2, 0.1), minor=True)
plt.tick_params(which='minor', length=0)
plt.xlabel('$x_0$')
plt.ylabel('$x_1$')
plt.grid()
plt.grid(which='minor', alpha=.25)
plt.show()

# %% [markdown]
# NEWTONS METHOD FOR ROOTS OF COUPLED NONLINEAR FUNCTIONS
#
# S. Linge and H. P. Langtangen: Programming for Computations

# %%
import numpy as np
from numpy import cos, sin, pi, exp
def f(x):
  f0 = x[0]**2 - 2*x[0] + x[1]**4 - 2*x[1]**2 + x[1];
  f1 = x[0]**2 + x[0] + 2*x[1]**3 - 2*x[1]**2 - 1.5*x[1] - 0.05;
  return np.array([f0,f1])
def J(x):
  df00=2*x[0]-2; df01=4*x[1]**3-4*x[1];df10=2*x[0]+1;df11=6*x[1]**2-4*x[1]-1.5;
  return np.array([[df00,df01],[df10,df11]])
def Newton_system(f, J, x, eps):
  f_value = f(x)
  f_norm = np.linalg.norm(f_value, ord=2) # l2 norm of vector
  iteration_counter = 0
  while abs(f_norm) > eps and iteration_counter < 100:
    delta = np.linalg.solve(J(x), -f_value)
    x = x + delta
    f_value = f(x)
    f_norm = np.linalg.norm(f_value, ord=2)
    iteration_counter += 1
# Here, either a solution is found, or too many iterations
  if abs(f_norm) > eps:
     iteration_counter = -1
  return x, iteration_counter
x=np.array([2.5, -1.5])
x, n = Newton_system(f, J, x, eps=0.00000001)
print(n, x)
# Out:
# 7 [ 2.45867009 -1.46907026]

# %%
from numpy import cos, sin, pi, exp
import numpy as np
import matplotlib.pyplot as plt
def f0(x0,x1):
    return x0*cos(x1) - 4
def f1(x0,x1):
    return x0*x1-x1-5
x0 = np.arange(-10.,10.,0.1)
x1 = np.arange(-10.,10.,0.1)
X0, X1 = np.meshgrid(x0,x1)
c1=plt.contour(x0, x1, f0(X0, X1),[0],colors=['b','g','m']);
c2=plt.contour(x0, x1, f1(X0, X1),[0],colors=['r','y','c']);
plt.clabel(c1, inline=True, fontsize=10)
plt.clabel(c2, inline=True, fontsize=10)
plt.xticks(np.arange(-10, 10, 1))
plt.yticks(np.arange(-10, 10, 1))
plt.xticks(np.arange(-10, 10, .5), minor=True)
plt.yticks(np.arange(-10, 10, .5), minor=True)
plt.tick_params(which='minor', length=0)
plt.xlabel('$x_0$')
plt.ylabel('$x_1$')
plt.grid()
plt.grid(which='minor', alpha=0.3)
plt.show()

# %%
import numpy as np
from numpy import cos, sin, pi, exp
def f(x):
  f0 = x[0]*cos(x[1]) - 4;
  f1 = x[0]*x[1]-x[1]-5;
  return np.array([f0,f1])
def J(x):
  df00=cos(x[1]); df01=-x[0]*sin(x[1]);df10=x[1];df11=x[0]-1;
  return np.array([[df00,df01],[df10,df11]])
def Newton_system(f, J, x, eps):
  f_value = f(x)
  f_norm = np.linalg.norm(f_value, ord=2) # l2 norm of vector
  iteration_counter = 0
  while abs(f_norm) > eps and iteration_counter < 100:
    delta = np.linalg.solve(J(x), -f_value)
    x = x + delta
    f_value = f(x)
    f_norm = np.linalg.norm(f_value, ord=2)
    iteration_counter += 1
# Here, either a solution is found, or too many iterations
  if abs(f_norm) > eps:
     iteration_counter = -1
  return x, iteration_counter
x=np.array([6, 1])
x, n = Newton_system(f, J, x, eps=0.00000001)
print(n, x)
# Out:
# 3 [6.50409711 0.90841421]

# %% [markdown]
# Using the Gezerlis code

# %%
import numpy as np
def termcrit(xolds,xnews):
  errs = np.abs((xnews - xolds)/xnews)
  return np.sum(errs)
def backsub(U,bs):
  n = bs.size
  xs = np.zeros(n)
  for i in reversed(range(n)):
    xs[i] = (bs[i] - U[i,i+1:]@xs[i+1:])/U[i,i]
  return xs

def gauelim_pivot(inA,inbs):
  A = np.copy(inA)
  bs = np.copy(inbs)
  n = bs.size
  for j in range(n-1):
    k = np.argmax(np.abs(A[j:,j])) + j
#fIND INDEX OF MAXIMUM ENTRY IN COLUMN j
    if k != j:
      A[j,:], A[k,:] = A[k,:], A[j,:].copy()
#INTERCHANGE ROWS j and k
      bs[j], bs[k] = bs[k], bs[j]
    for i in range(j+1,n):
      coeff = A[i,j]/A[j,j]
      A[i,j:] -= coeff*A[j,j:]
      bs[i] -= coeff*bs[j]
  xs = backsub(A,bs)
  return xs
def fs(xs):
    x0, x1 = xs
    f0 = x0**2 - 2*x0 + x1**4 - 2*x1**2 + x1
    f1 = x0**2 + x0 + 2*x1**3 - 2*x1**2 - 1.5*x1 - 0.05
    return np.array([f0,f1])

def jacobian(fs,xs,h=1.e-4):
    n = xs.size
    iden = np.identity(n)
    Jf = np.zeros((n,n))
    fs0 = fs(xs)
    for j in range(n):
        fs1 = fs(xs+iden[:,j]*h)
        Jf[:,j] = (fs1 - fs0)/h
    return Jf, fs0

def multi_newton(fs,jacobian,xolds,kmax=200,tol=1.e-8):
    for k in range(1,kmax):
        Jf, fs_xolds = jacobian(fs, xolds)
        xnews = xolds + gauelim_pivot(Jf, -fs_xolds)
        err = termcrit(xolds,xnews)
        print(k, xnews, err)
        if err < tol:
            break
        xolds = np.copy(xnews)
    else:
        xnews = None
    return xnews

xolds = np.array([2.5,-1.5])
xnews = multi_newton(fs,jacobian,xolds)
print(xnews); print(fs(xnews))
# Out:
# 1 [ 2.46048056 -1.47015814] 0.03636007145318218
# 2 [ 2.45867264 -1.4690716 ] 0.001474937109222195
# 3 [ 2.45867009 -1.46907026] 1.9467353597888955e-06
# 4 [ 2.45867009 -1.46907026] 1.472391688468175e-10
# [ 2.45867009 -1.46907026]
# [ 1.42108547e-13 -1.64937508e-13]

# %% [markdown]
# 1D MINIMIZATION
#
# Our example
#
# $f(x)=e^{x-\sqrt{x}}-x$

# %%
import numpy as np
from matplotlib import pyplot as plt
def f(x):
   return np.exp(x-np.sqrt(x))-x
def fprime(x):
   return np.exp(x-np.sqrt(x))*(1-0.5/np.sqrt(x))-1
def fdprime(x):
   return np.exp(x-np.sqrt(x))*(1-1/np.sqrt(x)+(2*x+1)/(8*x**2))
x = np.linspace(.0, 3, 100)

plt.plot(x, f(x), color='red', label='f')
plt.plot(x, 0*x, color='black')
plt.plot(x,fprime(x),color='blue',label='fprime')
plt.plot(x,fdprime(x),color='green',label='fdprime')
plt.ylim([-1, 1])
plt.legend()
plt.grid()
plt.show()
# Out:
# <ipython-input-7-820d2b9ae3e7>:6: RuntimeWarning: divide by zero encountered in divide
#   return np.exp(x-np.sqrt(x))*(1-0.5/np.sqrt(x))-1
# <ipython-input-7-820d2b9ae3e7>:8: RuntimeWarning: divide by zero encountered in divide
#   return np.exp(x-np.sqrt(x))*(1-1/np.sqrt(x)+(2*x+1)/(8*x**2))
# <ipython-input-7-820d2b9ae3e7>:8: RuntimeWarning: invalid value encountered in add
#   return np.exp(x-np.sqrt(x))*(1-1/np.sqrt(x)+(2*x+1)/(8*x**2))

# %% [markdown]
# 1D MINIMIZATION
#
# Figure 5.13
#
# $f(x)=4 x^{5} -15 x^{4} + 14 x^{3} + 4 $

# %%
import numpy as np
from matplotlib import pyplot as plt
def f(x):
   return 4*x**5-15*x**4+14*x**3+4
def fprime(x):
   return 20*x**4-60*x**3+42*x**2
def fdprime(x):
   return 80*x**3-180*x**2+84*x
x = np.linspace(-1.0, 3, 100)

plt.plot(x, f(x), color='red', label='f')
plt.plot(x, 0*x, color='black')
plt.plot(x,fprime(x),color='blue',label='fprime')
plt.plot(x,fdprime(x),color='green',label='fdprime')
plt.ylim([-15, 15])
plt.legend()
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
def f(x):
   return 1.6*x**3 + 3.0*x**2 - 2.0*x

x = np.linspace(-1.0, 2, 100)

plt.plot(x, f(x), color='red', label='f')
plt.plot(x, 0*x, color='black')

plt.ylim([-1., 1.5])
plt.legend()
plt.show()

# %%
# Author: Alex Gezerlis
# Numerical Methods in Physics with Python (2nd ed., CUP, 2023)

from math import sqrt, exp
#def f(x):
#  return exp(x - sqrt(x)) - x
def f(x):
    return 1.6*x**3 + 3.0*x**2 - 2.0*x
def golden(f, x0, x1, kmax=200, tol=1.e-8):
    varphi = 0.5*(1 + sqrt(5))
    for k in range(1,kmax):
        x2 = x0 + (x1-x0)/(varphi+1)
        x3 = x0 + (x1-x0)*varphi/(varphi+1)
        if f(x3) < f(x2):
            x0 = x2
        else:
            x1 = x3
        xnew = (x0+x1)/2
        xdiff = abs(x1-x0)
        rowf = "{0:2d} {1:1.16f} {2:1.16f} {3:1.16f}"
        print(rowf.format(k, xnew, xdiff, f(xnew)))
        if abs(xdiff) < tol:
            break
    else:
        xnew = None
    return xnew
val = golden(f,0.,1.0); print(val)
# Out:
#  1 0.3090169943749475 0.6180339887498949 -0.2843458848123580
#  2 0.1909830056250526 0.3819660112501052 -0.2613968679372004
#  3 0.2639320225002104 0.2360679774997897 -0.2894668524892745
#  4 0.3090169943749475 0.1458980337503155 -0.2843458848123580
#  5 0.2811529493745268 0.0901699437494742 -0.2896060889934776
#  6 0.2639320225002104 0.0557280900008412 -0.2894668524892745
#  7 0.2745751406263145 0.0344418537486330 -0.2898547435108554
#  8 0.2679973318781020 0.0212862362522082 -0.2897297427146002
#  9 0.2720626412559937 0.0131556174964248 -0.2898509529236720
# 10 0.2745751406263145 0.0081306187557833 -0.2898547435108554
# 11 0.2730223306187435 0.0050249987406414 -0.2898588257968734
# 12 0.2739820199814934 0.0031056200151418 -0.2898587586841716
# 13 0.2733888993366722 0.0019193787254996 -0.2898597378116761
# 14 0.2737554680546009 0.0011862412896422 -0.2898594909252822
# 15 0.2735289161277086 0.0007331374358574 -0.2898597803249069
# 16 0.2733888993366723 0.0004531038537848 -0.2898597378116761
# 17 0.2734754344725284 0.0002800335820726 -0.2898597840453280
# 18 0.2735289161277086 0.0001730702717122 -0.2898597803249069
# 19 0.2734958626470326 0.0001069633103603 -0.2898597855363524
# 20 0.2734754344725284 0.0000661069613519 -0.2898597840453280
# 21 0.2734880597787002 0.0000408563490085 -0.2898597853916949
# 22 0.2734958626470326 0.0000252506123435 -0.2898597855363524
# 23 0.2734910402091934 0.0000156057366650 -0.2898597855089362
# 24 0.2734940206396867 0.0000096448756784 -0.2898597855495574
# 25 0.2734958626470326 0.0000059608609865 -0.2898597855363524
# 26 0.2734947242238853 0.0000036840146919 -0.2898597855479680
# 27 0.2734940206396867 0.0000022768462946 -0.2898597855495574
# 28 0.2734944554786354 0.0000014071683972 -0.2898597855490791
# 29 0.2734941867333854 0.0000008696778974 -0.2898597855495672
# 30 0.2734940206396867 0.0000005374904999 -0.2898597855495574
# 31 0.2734941232912379 0.0000003321873975 -0.2898597855495916
# 32 0.2734940598490903 0.0000002053031023 -0.2898597855495811
# 33 0.2734940990584938 0.0000001268842952 -0.2898597855495917
# 34 0.2734941232912378 0.0000000784188071 -0.2898597855495915
# 35 0.2734941083145784 0.0000000484654882 -0.2898597855495922
# 36 0.2734941175706630 0.0000000299533190 -0.2898597855495920
# 37 0.2734941118500881 0.0000000185121692 -0.2898597855495922
# 38 0.2734941083145783 0.0000000114411497 -0.2898597855495922
# 39 0.2734941104996435 0.0000000070710194 -0.2898597855495922
# 0.2734941104996435

# %% [markdown]
# Gradient Descent in 1D

# %%
import numpy as np
def f(x):
  return 1.6*x**3 + 3.0*x**2 - 2.0*x
def df(x):
  return 4.8*x**2+6.0*x-2.0
x = -1.
tol = 0.0001
gamma = .1
counter = 0
while np.abs(df(x))>tol and counter<1000000:
  x = x - gamma*df(x)
  counter += 1
print("The local minimum occurs at approximately x=",x,"f(x)=",f(x))
print("steps taken:",counter-1)
# Out:
# The local minimum occurs at approximately x= 0.27349056110014736 f(x)= -0.2898597854952579
# steps taken: 8

# %% [markdown]
# Python code for gradient descent (from Gezerlis)
#
# $F(x, y, z) = 2x^2 + 3y^2 + z^2 + xy + xz - 2y$

# %%
import numpy as np
def termcrit(xolds,xnews):
  errs = np.abs((xnews - xolds)/xnews)
  return np.sum(errs)
def phi(xs):
  x0, x1, x2 = xs
  return 2.0*x0**2 + 3.0*x1**2 + x2**2 + x0*x1 + x0*x2 - 2.0*x1

def gradient(phi,xs,h=1.e-6):
  n = xs.size
  phi0 = phi(xs)
  Xph = (xs*np.ones((n,n))).T + np.identity(n)*h
  grad = (phi(Xph) - phi0)/h
  return grad
def descent(phi,gradient,xolds,gamma=.15,kmax=200,tol=1.e-8):
  for k in range(1,kmax):
    xnews = xolds - gamma*gradient(phi,xolds)
    err = termcrit(xolds,xnews)
    print(k, xnews, err, phi(xnews))
    if err < tol:
      break
    xolds = np.copy(xnews)
  else:
    xnews = None
  return xnews

xolds = np.array([1.,1.,1.])
xnews = descent(phi, gradient, xolds)
print(xnews)
# Out:
# 1 [0.0999997  0.24999955 0.54999985] 12.818219498488412 0.08999964010422201
# 2 [-0.08000033  0.30999955  0.36999979] 2.930026687001719 -0.23640015839199813
# 3 [-0.13400033  0.34299955  0.27099975] 0.8645082712172635 -0.3059760930884218
# 4 [-0.14570033  0.35439956  0.20979973] 0.4041757589974566 -0.32773290014829887
# 5 [-0.14291032  0.35729455  0.16871471] 0.271143031649386 -0.3374716929793133
# 6 [-0.13606582  0.35716555  0.13953669] 0.25977046276412485 -0.34271530406677897
# 7 [-0.12893196  0.35612598  0.11808541] 0.23990856941205974 -0.34572475833569205
# 8 [-0.12270479  0.35495194  0.10199943] 0.2117633422923644 -0.34748454783952826
# 9 [-0.11762492  0.35390046  0.08980517] 0.1819438639299977 -0.34851894013562296
# 10 [-0.11360611  0.35303333  0.08050721] 0.1533234596674437 -0.3491278106572043
# 11 [-0.11047383  0.3523438   0.07339581] 0.12720122062522318 -0.34948634588780736
# 12 [-0.10805077  0.351805    0.06794799] 0.10413298211494117 -0.3496974924306775
# 13 [-0.10618356  0.35138767  0.06377106] 0.08427132449730385 -0.34982184310700914
# 14 [-0.10474753  0.35106585  0.06056713] 0.06752498775444676 -0.34989507753049665
# 15 [-0.10364426  0.35081826  0.05810897] 0.05365310240657547 -0.34993820785769847
# 16 [-0.10279709  0.35062802  0.05622277] 0.04233250560222945 -0.34996360879691396
# 17 [-0.10214675  0.35048191  0.05477535] 0.03320813937492823 -0.3499785682581313
# 18 [-0.10164759  0.35036975  0.05366461] 0.02592868348042971 -0.3499873783602682
# 19 [-0.10126449  0.35028366  0.05281221] 0.020169024923302883 -0.34999256689086283
# 20 [-0.10097048  0.35021759  0.05215807] 0.015642037142972427 -0.3499956225562138
# 21 [-0.10074484  0.35016688  0.05165607] 0.012102634091467834 -0.3499974221088284
# 22 [-0.10057168  0.35012796  0.05127083] 0.009346858919454741 -0.34999848189895133
# 23 [-0.10043879  0.3500981   0.05097518] 0.007208199390356476 -0.3499991060226484
# 24 [-0.10033681  0.35007518  0.0507483 ] 0.005552677201955704 -0.34999947357196265
# 25 [-0.10025854  0.35005759  0.05057418] 0.004273678702279641 -0.34999969001964215
# 26 [-0.10019848  0.35004409  0.05044056] 0.0032870810674165037 -0.3499998174815124
# 27 [-0.10015239  0.35003373  0.05033801] 0.0025269369389666245 -0.3499998925391066
# 28 [-0.10011702  0.35002578  0.05025932] 0.0019418041096640392 -0.34999993673604485
# 29 [-0.10008987  0.35001968  0.05019892] 0.0014917054779950104 -0.3499999627596594
# 30 [-0.10006904  0.350015    0.05015258] 0.0011456664626556315 -0.34999997808161887
# 31 [-0.10005305  0.35001141  0.05011701] 0.0008797401529340716 -0.3499999871019714
# 32 [-0.10004078  0.35000865  0.05008972] 0.0006754453057998687 -0.3499999924118428
# 33 [-0.10003137  0.35000653  0.05006877] 0.00051853636683654 -0.34999999553706324
# 34 [-0.10002414  0.35000491  0.05005269] 0.00039804528375653766 -0.3499999973761156
# 35 [-0.1000186   0.35000366  0.05004036] 0.00030553320868652024 -0.34999999845804575
# 36 [-0.10001434  0.35000271  0.05003089] 0.00023451113166644892 -0.34999999909434687
# 37 [-0.10001108  0.35000197  0.05002362] 0.0001799912376427319 -0.349999999468406
# 38 [-0.10000857  0.35000141  0.05001805] 0.00013814258425074084 -0.3499999996881799
# 39 [-0.10000665  0.35000098  0.05001377] 0.00010602166331405995 -0.3499999998172113
# 40 [-0.10000517  0.35000064  0.05001049] 8.13680807105063e-05 -0.3499999998928943
# 41 [-0.10000404  0.35000039  0.05000797] 6.24462579598302e-05 -0.34999999993722997
# 42 [-0.10000317  0.35000019  0.05000603] 4.792439831965483e-05 -0.3499999999631593
# 43 [-0.1000025   0.35000004  0.05000455] 3.677917561854543e-05 -0.34999999997829057
# 44 [-0.10000199  0.34999993  0.05000341] 2.8225766026309423e-05 -0.349999999987095
# 45 [-0.1000016   0.34999984  0.05000253] 2.16615565657117e-05 -0.34999999999219805
# 46 [-0.10000129  0.34999977  0.05000186] 1.6623734536194005e-05 -0.3499999999951404
# 47 [-0.10000106  0.34999972  0.05000135] 1.2757575926090386e-05 -0.349999999996825
# 48 [-0.10000089  0.34999968  0.05000095] 9.790585245629592e-06 -0.34999999999777986
# 49 [-0.10000075  0.34999965  0.05000065] 7.513388943987424e-06 -0.34999999999831377
# 50 [-0.10000065  0.34999963  0.05000042] 5.766175288456543e-06 -0.34999999999860637
# 51 [-0.10000056  0.34999961  0.05000024] 4.425034006628951e-06 -0.34999999999876175
# 52 [-0.1000005  0.3499996  0.0500001] 3.3956798417434853e-06 -0.3499999999988406
# 53 [-0.10000046  0.34999959  0.05      ] 2.606151397235926e-06 -0.34999999999887704
# 54 [-0.10000042  0.34999958  0.04999992] 1.999794395929236e-06 -0.349999999998891
# 55 [-0.10000039  0.34999957  0.04999985] 1.5348224301964767e-06 -0.3499999999988933
# 56 [-0.10000037  0.34999957  0.04999981] 1.1777988534248765e-06 -0.34999999999889025
# 57 [-0.10000035  0.34999956  0.04999977] 9.038868932527745e-07 -0.349999999998885
# 58 [-0.10000034  0.34999956  0.04999974] 6.936024039547925e-07 -0.3499999999988794
# 59 [-0.10000033  0.34999956  0.04999972] 5.324214328722847e-07 -0.34999999999887393
# 60 [-0.10000032  0.34999956  0.0499997 ] 4.084131154851679e-07 -0.34999999999886905
# 61 [-0.10000032  0.34999955  0.04999969] 3.1361956138964555e-07 -0.34999999999886533
# 62 [-0.10000031  0.34999955  0.04999968] 2.4072520993441715e-07 -0.34999999999886194
# 63 [-0.10000031  0.34999955  0.04999967] 1.845794102535343e-07 -0.34999999999885945
# 64 [-0.10000031  0.34999955  0.04999967] 1.417206498093032e-07 -0.3499999999988572
# 65 [-0.10000031  0.34999955  0.04999966] 1.0875877057236696e-07 -0.34999999999885567
# 66 [-0.1000003   0.34999955  0.04999966] 8.360020596146105e-08 -0.34999999999885434
# 67 [-0.1000003   0.34999955  0.04999966] 6.39967452822877e-08 -0.34999999999885334
# 68 [-0.1000003   0.34999955  0.04999966] 4.9115719596720584e-08 -0.3499999999988526
# 69 [-0.1000003   0.34999955  0.04999966] 3.781517916883193e-08 -0.34999999999885206
# 70 [-0.1000003   0.34999955  0.04999965] 2.8810433747629555e-08 -0.34999999999885156
# 71 [-0.1000003   0.34999955  0.04999965] 2.226801496941033e-08 -0.3499999999988511
# 72 [-0.1000003   0.34999955  0.04999965] 1.698649793715495e-08 -0.349999999998851
# 73 [-0.1000003   0.34999955  0.04999965] 1.3096734327815572e-08 -0.3499999999988507
# 74 [-0.1000003   0.34999955  0.04999965] 9.920686098887165e-09 -0.3499999999988506
# [-0.1000003   0.34999955  0.04999965]

# %% [markdown]
# Straight line fit
#
# Kisuallis Example 3.10

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
xData = np.array([0,1,2,2.5,3])
yData = np.array([2.9,3.7,4.1,4.4,5])
n=len(xData)
z=np.zeros(n)
xx=np.zeros(n)
xbar=sum(xData)/n
ybar=sum(yData)/n
xbx=xbar*sum(xData)
for i in range(n):
    z[i]=z[i]+np.array(xData[i]*yData[i])
    xx[i]=xx[i]+np.array(xData[i]*xData[i])
b=(sum(z)-xbar*sum(yData))/(sum(xx)-xbx)
a=ybar-b*xbar
print(xbar,ybar,b,a)
s0=0
for i in range(n):
    s=s0+(yData[i]-(a+b*xData[i]))**2
    s0=s
print(np.sqrt(s/(n-2)))

plt.plot(xData, yData, 'o')  # 'o' specifies that the points should be plotted as circles
plt.plot(xData,a+b*xData)
# Add labels and title
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Simple Plot of Data Points')

# Show the plot
plt.show()
# Out:
# 1.7 4.0200000000000005 0.6431034482758614 2.926724137931036
# 0.1519036294618342
