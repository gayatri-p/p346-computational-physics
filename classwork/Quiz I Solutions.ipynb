# %% [markdown]
# **QUIZ 1  (P346/P745)  Full Marks: 10**
#
#  TIME: 2 hours, ANSWER ALL QUESTIONS SERIALLY AND CONTINUOUSLY.
#
#  PARTS OF SAME QUESTION SHOULD BE ANSWERED ONE AFTER THE OTHER.

# %% [markdown]
# 1. (a) The following code enables a matrix operation. If
# $ A = \begin{bmatrix} 1 & 3 \\ 7 & 5 \end{bmatrix}$ and $B=\begin{bmatrix} 6 & 8 \\ 4 & 2 \end{bmatrix}$, then C = _____ . \\
# (b) What is the advantage of doing the operation this way over the traditional method?
# (2 marks)

# %%
import numpy as np
def XXX(A, B):
    A11 = A[0,0]
    A12 = A[0,1]
    A21 = A[1,0]
    A22 = A[1, 1]
    B11 = B[0, 0]
    B12 = B[0, 1]
    B21 = B[1, 0]
    B22 = B[1, 1]
    P1 = (A11 + A22) * (B11 + B22)
    P2 = (A21 + A22) * B11
    P3 = A11 * (B12 - B22)
    P4 = A22 * (B21 - B11)
    P5 = (A11 + A12) * B22
    P6 = (A21 - A11) * (B11 + B12)
    P7 = (A12 - A22) * (B21 + B22)
    C11 = P1 + P4 - P5 + P7
    C12 = P3 + P5
    C21 = P2 + P4
    C22 = P1 - P2 + P3 + P6
    C = np.array([[C11,C12],[C21,C22]])
    return C
C = XXX(A, B)
print(C)
# Out:
# [[18 14]
#  [62 66]]

# %% [markdown]
# https://www.quantamagazine.org/ai-reveals-new-possibilities-in-matrix-multiplication-20221123/

# %% [markdown]
# 2. Using Taylor's series expansion, write the first central difference approximation to the third derivative, what is the approximation error and round off error. Calculate the optimum error and step size $h$. (2 marks)

# %% [markdown]
# \begin{eqnarray}
# f(x-2h) &=& f(x) - 2hf'(x) + 4h^2 \frac{f''(x)}{2} - 8h^3 \frac{f'''(x)}{3!} + 16 h^4 \frac{f^{(4)}(x)}{4!} + \cdots \\
# f(x-h) &=& f(x) - h f'(x) + h^2 \frac{f''(x)}{2} - h^3 \frac{f'''(x)}{3!} + h^4 \frac{f^{(4)}(x)}{4!}+ \cdots \\
# f(x+h) &=& f(x) + h f'(x) + h^2 \frac{f''(x)}{2} + h^3 \frac{f'''(x)}{3!} + h^4 \frac{f^{(4)}(x)}{4!} + \cdots \\
# f(x+2h) &=& f(x) + 2h f'(x) + 4h^2 \frac{f''(x)}{2} + 8h^3 \frac{f'''(x)}{3!} + 16 h^4 \frac{f^{(4)}(x)}{4!} + \cdots \\
# \end{eqnarray}
#
#
# $f'''(x) \simeq \frac{−\frac{1}{2}f(x−2h)+f(x−h)−f(x+h)+\frac{1}{2}f(x+2h)}{h^{3}}$
#
#
# for the third derivative:
# $$-\frac{1}{2}f(x-2h) + f(x-h)-f(x+h)+\frac{1}{2}f(x+2h) = 0 f(x) + 0f'(x) + 0f''(x) + h^3 f'''(x) + 0 f^{(4)}(x) + \mathcal{O}(h^5) $$
# Solve for $f'''(x)$ gives us the order of the error: $\mathcal{O}(h^2)$

# %% [markdown]
# 3. (a) Convert the decimal number $(16)_{10}$ to ternary.
#
#   (b) Convert the decimal number $(0.1)_{10}$ to binary. (1 mark)
#
#
#   https://www.quantamagazine.org/how-base-3-computing-beats-binary-20240809/
#
#
# But mathematicians have long explored counting in threes. Consider, for example, base 3, or ternary, which uses three digits. The standard convention is to use the digits zero, 1 and 2.
#
#
# Graphic explaining how to count in threes.
# Mark Belan for Quanta Magazine
#
# ![image.png](data:image/png;base64,...)
# The hallmark feature of ternary notation is that it’s ruthlessly efficient. With two binary bits, you can represent four numbers. Two “trits” — each with three different states — allow you to represent nine different numbers. A number that requires 42 bits would need only 27 trits.
#
# If a three-state system is so efficient, you might imagine that a four-state or five-state system would be even more so. But the more digits you require, the more space you’ll need. It turns out that ternary is the most economical of all possible integer bases for representing big numbers.
#
# To see why, consider an important metric that tallies up how much room a system will need to store data. You start with the base of the number system, which is called the radix, and multiply it by the number of digits needed to represent some large number in that radix. For example, the number 100,000 in base 10 requires six digits. Its “radix economy” is therefore 10 × 6 = 60. In base 2, the same number requires 17 digits, so its radix economy is 2 × 17 = 34. And in base 3, it requires 11 digits, so its radix economy is 3 × 11 = 33. For large numbers, base 3 has a lower radix economy than any other integer base. (Surprisingly, if you allow a base to be any real number, and not just an integer, then the most efficient computational base is the irrational number e.)
#
#
# Quaternary
#
# The base-4 method of counting in which only the digits 0, 1, 2, and 3 are used. The illustration above shows the numbers 0 to 63 represented in quaternary, and the following table gives the quaternary equivalents of the first few decimal numbers.
#
# $1	| 1, 	 2	| 2	  , 3	| 3, 	4 |	10	$
#
# Quinary (base 5 or pental[1][2][3]) is a numeral system with five as the base. A possible origination of a quinary system is that there are five digits on either hand.
#
# In the quinary place system, five numerals, from 0 to 4, are used to represent any real number. According to this method, five is written as 10, twenty-five is written as 100, and sixty is written as 220.
#
# As five is a prime number, only the reciprocals of the powers of five terminate, although its location between two highly composite numbers (4 and 6) guarantees that many recurring fractions have relatively short periods.
#
# Today, the main usage of quinary is as a biquinary system, which is decimal using five as a sub-base. Another example of a sub-base system is sexagesimal (base sixty), which used ten as a sub-base.
#
# Each quinary digit can hold $\log_{2}5$ (approx.$ 2.32$) bits of information.
#
#
#
# $$0.1_{10} \approx 0.00011001100110011001100_2$$$$0.1_{10} \approx 0.00011001100110011001100_2$$

# %% [markdown]
# 4. Apply the Richardson extrapolation on the first central finite difference approximation for $f ′′(x)$.    Comment on approximation error and optimum step size. (2marks)

# %% [markdown]
# 5. Classify each of the following matrices as well-conditioned or ill-conditioned, based on (i) solving system of linear equations and (ii) determining eigenvalues.
#
# (a) $\Bigg(\begin{matrix} 10^{10}& 0 \\ 0 & 10^{10}\end{matrix}\Bigg)$,
# (b) $\Bigg(\begin{matrix} 10^{-10}& 0 \\ 0 & 10^{-10}\end{matrix}\Bigg)$,
# (c) $\Bigg(\begin{matrix} 10^{10}& 0 \\ 0 & 10^{-10}\end{matrix}\Bigg)$,
# (d) $\Bigg(\begin{matrix} 1& 2 \\ 2 & 4\end{matrix}\Bigg)$. (2 marks)

# %% [markdown]
# CONDITION NUMBER FOR SOLVING SYSTEM OF LINEAR EQUATIONS

# %%
import numpy as np
A1 = np.array([[10**10,0], [0,10**10]])
A2 = np.array([[10**-10,0],[0,10**-10]])
A3 = np.array([[10**10,0],[0,10**-10]])
A4 = np.array([[1,2], [2,4]])


print(np.linalg.norm(np.linalg.inv(A1))*np.linalg.norm(A1))
print(np.linalg.norm(np.linalg.inv(A2))*np.linalg.norm(A2))
print(np.linalg.norm(np.linalg.inv(A3))*np.linalg.norm(A3))
print(np.linalg.norm(np.linalg.inv(A4))*np.linalg.norm(A4))
# Out:
# 2.0
# 2.0
# 1e+20
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-1-40abf6ed7019> in <cell line: 11>()
#       9 print(np.linalg.norm(np.linalg.inv(A2))*np.linalg.norm(A2))
#      10 print(np.linalg.norm(np.linalg.inv(A3))*np.linalg.norm(A3))
# ---> 11 print(np.linalg.norm(np.linalg.inv(A4))*np.linalg.norm(A4))
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in inv(a)
#     559     signature = 'D->D' if isComplexType(t) else 'd->d'
#     560     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 561     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     562     return wrap(ainv.astype(result_t, copy=False))
#     563
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#     110
#     111 def _raise_linalgerror_singular(err, flag):
# ...

# %% [markdown]
# CONDITION NUMBER FOR EIGEN **VALUES**

# %%
import numpy as np
from scipy.linalg import eig
A1 = np.array([[10**10,0], [0,10**10]])
A2 = np.array([[10**-10,0],[0,10**-10]])
A3 = np.array([[10**10,0],[0,10**-10]])
A4 = np.array([[1,2], [2,4]])

w,v=np.linalg.eig(A1)
print('E-value:', w)
print('E-vector', v)
w, vl, vr = eig(A1, left=True)
idx = np.argsort(w)[::-1]
eigenValues = w[idx]
LeigenVectors =vl[:,idx]
eigenVectors = vr[:,idx]
print(eigenValues, eigenVectors)
vr3=eigenVectors[:,1]
vl3=LeigenVectors[:,1]
print(vr3)
vlt3=vl3.T
K1=1/abs(np.matmul(vlt3,vr3))
print("condition no.=",K1)
vr30=eigenVectors[:,0]
vl30=LeigenVectors[:,0]
print(vr30)
vlt30=vl30.T
K0=1/abs(np.matmul(vlt30,vr30))
print("condition no.=",K0)
w,v=np.linalg.eig(A2)
print('E-value:', w)
print('E-vector', v)
w, vl, vr = eig(A2, left=True)
idx = np.argsort(w)[::-1]
eigenValues = w[idx]
LeigenVectors =vl[:,idx]
eigenVectors = vr[:,idx]
print(eigenValues, eigenVectors)
vr3=eigenVectors[:,1]
vl3=LeigenVectors[:,1]
print(vr3)
vlt3=vl3.T
K1=1/abs(np.matmul(vlt3,vr3))
print("condition no.=",K1)
vr30=eigenVectors[:,0]
vl30=LeigenVectors[:,0]
print(vr30)
vlt30=vl30.T
K0=1/abs(np.matmul(vlt30,vr30))
print("condition no.=",K0)
w,v=np.linalg.eig(A3)
print('E-value:', w)
print('E-vector', v)
w, vl, vr = eig(A3, left=True)
idx = np.argsort(w)[::-1]
eigenValues = w[idx]
LeigenVectors =vl[:,idx]
eigenVectors = vr[:,idx]
print(eigenValues, eigenVectors)
vr3=eigenVectors[:,1]
vl3=LeigenVectors[:,1]
print(vr3)
vlt3=vl3.T
K1=1/abs(np.matmul(vlt3,vr3))
print("condition no.=",K1)
vr30=eigenVectors[:,0]
vl30=LeigenVectors[:,0]
print(vr30)
vlt30=vl30.T
K0=1/abs(np.matmul(vlt30,vr30))
print("condition no.=",K0)
w,v=np.linalg.eig(A4)
print('E-value:', w)
print('E-vector', v)
w, vl, vr = eig(A4, left=True)
idx = np.argsort(w)[::-1]
eigenValues = w[idx]
LeigenVectors =vl[:,idx]
eigenVectors = vr[:,idx]
print(eigenValues, eigenVectors)
vr3=eigenVectors[:,1]
vl3=LeigenVectors[:,1]
print(vr3)
vlt3=vl3.T
K1=1/abs(np.matmul(vlt3,vr3))
print("condition no.=",K1)
vr30=eigenVectors[:,0]
vl30=LeigenVectors[:,0]
print(vr30)
vlt30=vl30.T
K0=1/abs(np.matmul(vlt30,vr30))
print("condition no.=",K0)
# Out:
# E-value: [1.e+10 1.e+10]
# E-vector [[1. 0.]
#  [0. 1.]]
# [1.e+10+0.j 1.e+10+0.j] [[0. 1.]
#  [1. 0.]]
# [1. 0.]
# condition no.= 1.0
# [0. 1.]
# condition no.= 1.0
# E-value: [1.e-10 1.e-10]
# E-vector [[1. 0.]
#  [0. 1.]]
# [1.e-10+0.j 1.e-10+0.j] [[0. 1.]
#  [1. 0.]]
# [1. 0.]
# condition no.= 1.0
# [0. 1.]
# condition no.= 1.0
# E-value: [1.e+10 1.e-10]
# E-vector [[1. 0.]
#  [0. 1.]]
# [1.e+10+0.j 1.e-10+0.j] [[1. 0.]
#  [0. 1.]]
# [0. 1.]
# condition no.= 1.0
# [1. 0.]
# condition no.= 1.0
# E-value: [0. 5.]
# E-vector [[-0.89442719 -0.4472136 ]
#  [ 0.4472136  -0.89442719]]
# [5.+0.j 0.+0.j] [[-0.4472136  -0.89442719]
#  [-0.89442719  0.4472136 ]]
# [-0.89442719  0.4472136 ]
# condition no.= 1.0000000000000002
# [-0.4472136  -0.89442719]
# condition no.= 1.0000000000000002

# %% [markdown]
# 6. Explicitly show how automatic differentiation works on the following function: $f (x) = \frac {(x − 5)(x − 6) \sqrt{x}}{ x − 7} $ to evaluate $f (4)$ and $f′(4)$. (1 mark)

# %%
import jax
import jax.numpy as jnp
from math import sqrt
def f(x):
    return (x-5)*(x-6)*jnp.sqrt(x)/(x-7)
print(f(4.0))
print(jax.grad(f)(4.0))
print(25/18)
# Out:
# -1.3333334
# 1.388889
# 1.3888888888888888

# %% [markdown]
# $f(x)=x^{4} -9 x^{3} +25 x^{2} -24 x +4 $

# %%
import numpy as np
from matplotlib import pyplot as plt
def f(x):
   return x**4-9*x**3+25*x**2-24*x+4
def fprime(x):
   return 4*x**3-27*x**2+50*x-24
def fdprime(x):
   return 12*x**2-54*x+50
x = np.linspace(0, 5, 100)

plt.plot(x, f(x), color='red')
plt.plot(x, 0*x, color='black')
plt.plot(x,fprime(x),color='blue')
plt.plot(x,fdprime(x),color='green')
plt.ylim([-15, 10])
plt.show()

# %%
#Newtons method for Fig 5.8
from math import exp, sqrt, log
def f(x):
    return x**4-9*x**3+25*x**2-24*x+4
def fprime(x):
    return 4*x**3-27*x**2+50*x-24
def newton(f,fprime,xold,kmax=200,eps=1.e-8):
    for k in range(1,kmax):
        xnew = xold - 2*f(xold)/fprime(xold)
        xdiff = xnew - xold
        print("{0:2d} {1:1.16f} {2:1.16f}".format(k,xnew,xdiff))
        if abs(xdiff/(1+xnew)) < eps:
            break
        xold = xnew
    else:
        xnew = None
    return xnew
root=newton(f,fprime,1.9)
print(root);print("")
# Out:
#  1 2.0012422360248228 0.1012422360248229
#  2 2.0000001538750336 -0.0012420821497892
#  3 2.0000000245805327 -0.0000001292945009
#  4 2.0000000245805327 0.0000000000000000
# 2.0000000245805327
